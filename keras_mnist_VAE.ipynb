# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from keras.datasets import mnist
from keras.layers import Input, Dense, Lambda
from keras.models import Model
from keras import backend as K
from keras.losses import binary_crossentropy
from scipy.stats import norm

plt.style.use('ggplot')

# %%
# data load
(x_tr, y_tr), (x_te, y_te) = mnist.load_data()
x_tr, x_te = x_tr.astype('float32')/255., x_te.astype('float32')/255.
x_tr, x_te = x_tr.reshape(x_tr.shape[0], -1), x_te.reshape(x_te.shape[0], -1)
print(x_tr.shape, x_te.shape)

batch_size, n_epoch = 100, 100
n_hidden, z_dim = 256, 2
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# (60000, 784) (10000, 784)

# %%
# encoder
x = Input(shape=(x_tr.shape[1:]))
x_encoded = Dense(n_hidden, activation='relu')(x)
x_encoded = Dense(n_hidden//2, activation='relu')(x_encoded)

mu = Dense(z_dim)(x_encoded)
log_var = Dense(z_dim)(x_encoded)

# %%
# sampling function
def sampling(args):
    mu, log_var = args
    eps = K.random_normal(shape=(batch_size, z_dim), mean=0., stddev=1.0)
    return mu + K.exp(log_var) * eps

z = Lambda(sampling, output_shape=(z_dim,))([mu, log_var])

# %%
# decoder
z_decoder1 = Dense(n_hidden//2, activation='relu')
z_decoder2 = Dense(n_hidden, activation='relu')
y_decoder = Dense(x_tr.shape[1], activation='sigmoid')

z_decoded = z_decoder1(z)
z_decoded = z_decoder2(z_decoded)
y = y_decoder(z_decoded)

# %%
# loss
reconstruction_loss = binary_crossentropy(x, y) * x_tr.shape[1]
kl_loss = 0.5 * K.sum(K.square(mu) + K.exp(log_var) - log_var - 1, axis = -1)
vae_loss = reconstruction_loss + kl_loss

# build model
vae = Model(x, y)
vae.add_loss(vae_loss)
vae.compile(optimizer='rmsprop')
vae.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 784)]        0           []
#
#  dense (Dense)                  (None, 256)          200960      ['input_1[0][0]']
#
#  dense_1 (Dense)                (None, 128)          32896       ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 2)            258         ['dense_1[0][0]']
#
#  dense_3 (Dense)                (None, 2)            258         ['dense_1[0][0]']
#
#  lambda (Lambda)                (100, 2)             0           ['dense_2[0][0]',
#                                                                   'dense_3[0][0]']
#
#  dense_4 (Dense)                (100, 128)           384         ['lambda[0][0]']
#
#  dense_5 (Dense)                (100, 256)           33024       ['dense_4[0][0]']
#
#  dense_6 (Dense)                (100, 784)           201488      ['dense_5[0][0]']
#
#  tf.math.square (TFOpLambda)    (None, 2)            0           ['dense_2[0][0]']
#
#  tf.math.exp (TFOpLambda)       (None, 2)            0           ['dense_3[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 2)           0           ['tf.math.square[0][0]',
#  da)                                                              'tf.math.exp[0][0]']
#
#  tf.cast (TFOpLambda)           (None, 784)          0           ['input_1[0][0]']
#
#  tf.convert_to_tensor (TFOpLamb  (100, 784)          0           ['dense_6[0][0]']
#  da)
#
#  tf.math.subtract (TFOpLambda)  (None, 2)            0           ['tf.__operators__.add[0][0]',
#                                                                   'dense_3[0][0]']
#
#  tf.keras.backend.binary_crosse  (100, 784)          0           ['tf.cast[0][0]',
#  ntropy (TFOpLambda)                                              'tf.convert_to_tensor[0][0]']
#
#  tf.math.subtract_1 (TFOpLambda  (None, 2)           0           ['tf.math.subtract[0][0]']
#  )
#
#  tf.math.reduce_mean (TFOpLambd  (100,)              0           ['tf.keras.backend.binary_crossen
#  a)                                                              tropy[0][0]']
#
#  tf.math.reduce_sum (TFOpLambda  (None,)             0           ['tf.math.subtract_1[0][0]']
#  )
#
#  tf.math.multiply (TFOpLambda)  (100,)               0           ['tf.math.reduce_mean[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None,)             0           ['tf.math.reduce_sum[0][0]']
#  )
#
#  tf.__operators__.add_1 (TFOpLa  (100,)              0           ['tf.math.multiply[0][0]',
#  mbda)                                                            'tf.math.multiply_1[0][0]']
#
#  add_loss (AddLoss)             (100,)               0           ['tf.__operators__.add_1[0][0]']
#
# ==================================================================================================
# Total params: 469,268
# Trainable params: 469,268
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# train
vae.fit(x_tr,
       shuffle=True,
       epochs=n_epoch,
       batch_size=batch_size,
       validation_data=(x_te, None), verbose=1)
# Out:
# Epoch 1/100
# 600/600 [==============================] - 7s 6ms/step - loss: 188.0511 - val_loss: 168.3907
# Epoch 2/100
# 600/600 [==============================] - 3s 6ms/step - loss: 164.3382 - val_loss: 161.2379
# Epoch 3/100
# 600/600 [==============================] - 4s 6ms/step - loss: 157.3422 - val_loss: 155.3589
# Epoch 4/100
# 600/600 [==============================] - 5s 8ms/step - loss: 152.8226 - val_loss: 151.3961
# Epoch 5/100
# 600/600 [==============================] - 6s 10ms/step - loss: 150.2050 - val_loss: 149.5806
# Epoch 6/100
# 600/600 [==============================] - 4s 7ms/step - loss: 148.2093 - val_loss: 148.1347
# Epoch 7/100
# 600/600 [==============================] - 4s 6ms/step - loss: 146.7148 - val_loss: 146.2841
# Epoch 8/100
# 600/600 [==============================] - 4s 6ms/step - loss: 145.4218 - val_loss: 144.8548
# Epoch 9/100
# 600/600 [==============================] - 4s 7ms/step - loss: 144.3649 - val_loss: 144.0266
# Epoch 10/100
# 600/600 [==============================] - 4s 6ms/step - loss: 143.4998 - val_loss: 143.6781
# Epoch 11/100
# 600/600 [==============================] - 4s 6ms/step - loss: 142.7858 - val_loss: 142.9621
# Epoch 12/100
# 600/600 [==============================] - 4s 6ms/step - loss: 142.1124 - val_loss: 142.7707
# Epoch 13/100
# 600/600 [==============================] - 5s 8ms/step - loss: 141.6108 - val_loss: 142.5255
# Epoch 14/100
# 600/600 [==============================] - 4s 7ms/step - loss: 141.1764 - val_loss: 141.5799
# Epoch 15/100
# 600/600 [==============================] - 3s 6ms/step - loss: 140.7924 - val_loss: 141.5698
# Epoch 16/100
# 600/600 [==============================] - 3s 6ms/step - loss: 140.4437 - val_loss: 141.2340
# Epoch 17/100
# 600/600 [==============================] - 3s 6ms/step - loss: 140.1675 - val_loss: 140.7325
# Epoch 18/100
# 600/600 [==============================] - 4s 6ms/step - loss: 139.7350 - val_loss: 141.0061
# Epoch 19/100
# 600/600 [==============================] - 3s 6ms/step - loss: 139.4604 - val_loss: 141.5819
# Epoch 20/100
# 600/600 [==============================] - 3s 6ms/step - loss: 139.1628 - val_loss: 140.0826
# Epoch 21/100
# 600/600 [==============================] - 4s 6ms/step - loss: 138.9409 - val_loss: 140.8830
# Epoch 22/100
# 600/600 [==============================] - 3s 6ms/step - loss: 138.6783 - val_loss: 140.1377
# Epoch 23/100
# 600/600 [==============================] - 4s 6ms/step - loss: 133.8504 - val_loss: 137.6177
# Epoch 82/100
# 600/600 [==============================] - 4s 6ms/step - loss: 133.9265 - val_loss: 137.7119
# Epoch 83/100
# 600/600 [==============================] - 4s 6ms/step - loss: 133.8701 - val_loss: 137.5356
# Epoch 84/100
# 600/600 [==============================] - 3s 6ms/step - loss: 133.8885 - val_loss: 137.5073
# Epoch 85/100
# 600/600 [==============================] - 3s 6ms/step - loss: 133.6763 - val_loss: 138.5221
# Epoch 86/100
# 600/600 [==============================] - 3s 6ms/step - loss: 133.7058 - val_loss: 137.4512
# Epoch 87/100
# 600/600 [==============================] - 4s 6ms/step - loss: 133.6725 - val_loss: 137.7179
# Epoch 88/100
# 600/600 [==============================] - 3s 6ms/step - loss: 133.5649 - val_loss: 137.8455
# Epoch 89/100
# 600/600 [==============================] - 3s 6ms/step - loss: 133.6765 - val_loss: 138.2667
# Epoch 90/100
# 600/600 [==============================] - 3s 6ms/step - loss: 133.7486 - val_loss: 137.5960
# Epoch 91/100
# 600/600 [==============================] - 4s 6ms/step - loss: 133.5789 - val_loss: 137.5288
# Epoch 92/100
# 600/600 [==============================] - 3s 6ms/step - loss: 133.5007 - val_loss: 138.0258
# Epoch 93/100
# 600/600 [==============================] - 4s 6ms/step - loss: 133.4733 - val_loss: 139.2021
# Epoch 94/100
# 600/600 [==============================] - 3s 6ms/step - loss: 133.4086 - val_loss: 137.5256
# Epoch 95/100
# 600/600 [==============================] - 4s 6ms/step - loss: 133.4468 - val_loss: 137.9542
# Epoch 96/100
# 600/600 [==============================] - 4s 6ms/step - loss: 133.3886 - val_loss: 138.3553
# Epoch 97/100
# 600/600 [==============================] - 3s 6ms/step - loss: 133.3857 - val_loss: 137.8971
# Epoch 98/100
# 600/600 [==============================] - 3s 6ms/step - loss: 134.0195 - val_loss: 137.6872
# Epoch 99/100
# 600/600 [==============================] - 4s 6ms/step - loss: 133.4727 - val_loss: 138.3074
# Epoch 100/100
# 600/600 [==============================] - 3s 6ms/step - loss: 133.2787 - val_loss: 137.6051

# %%
# build encoder
encoder = Model(x, mu)
encoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 784)]             0
#
#  dense (Dense)               (None, 256)               200960
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 234,114
# Trainable params: 234,114
# Non-trainable params: 0
# _________________________________________________________________

# %%
# latent space
plt.figure(figsize=(12, 12))
x_te_latent = encoder.predict(x_te, batch_size=batch_size)
plt.scatter(x_te_latent[:, 0], x_te_latent[:, 1], c=y_te)
plt.colorbar()
plt.show()

# %%
# build decoder
decoder_input = Input(shape=(z_dim,))
_z_decoded = z_decoder1(decoder_input)
_z_decoded = z_decoder2(_z_decoded)
_y = y_decoder(_z_decoded)
generator = Model(decoder_input, _y)
generator.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 2)]               0
#
#  dense_4 (Dense)             multiple                  384
#
#  dense_5 (Dense)             multiple                  33024
#
#  dense_6 (Dense)             multiple                  201488
#
# =================================================================
# Total params: 234,896
# Trainable params: 234,896
# Non-trainable params: 0
# _________________________________________________________________

# %%
# display a 2D manifold of the digits
n = 15 # figure with 15x15 digits
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))

grid_x = norm.ppf(np.linspace(0.05, 0.95, n)) 
grid_y = norm.ppf(np.linspace(0.05, 0.95, n))

for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
        z_sample = np.array([[xi, yi]])
        x_decoded = generator.predict(z_sample)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        figure[i * digit_size: (i + 1) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit

plt.figure(figsize=(12, 12))
plt.imshow(figure, cmap='gray')
plt.show()
